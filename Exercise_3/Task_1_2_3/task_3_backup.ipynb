# %%
from task_3 import phase_portrait, orbit_plot, cusp_bifurcation_surface

# %%
alphas = [-1.8, 0, 1.3]
for alpha in alphas:
    phase_portrait(alpha)

# %%
starting_points = [[2,0], [0.5,0]]
for starting_point in starting_points:
    orbit_plot(starting_point)

# %%
cusp_bifurcation_surface(view_angle=(30,60))
